# %%
import os
os.chdir("C:\PyProj\Datasets")

# %%
import os 
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('hrdata.csv')
data2=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
data2.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(data.Income, bins=10, alpha=0.5, color="blue", linewidth=3)
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
data.Income.plot('density', ls='--')
plt.xlabel("Income")
plt.title("Density plot for Income")
plt.rcParams['xtick.labelsize']=8
plt.tight_layout()

# %%
ax=data["Income"].plot(kind="hist",color="lightblue",ylim=(0,400))
ax2=data["Income"].plot(kind="density",color="blue",secondary_y=True,ax=ax)

ax.set_ylabel("No of Employees")
ax2.set_ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.boxplot(data["Income"], patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26560d8c2e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26560d8ca20>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x26560d8c0b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x26560d8ce10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26560d97438>],
#  'means': []}

# %%
data2.plot(kind="box", color="red", subplots=True, layout=(2,2))
plt.tight_layout()

# %%
sns.boxplot(data=data2, orient="h",palette="Set2")

# %%
bp=plt.boxplot(data["Income"])
bp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2656119dc18>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x265611ab358>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2656119d828>],
#  'medians': [<matplotlib.lines.Line2D at 0x265611ab9e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x265611abd30>],
#  'means': []}

# %%
a=bp["fliers"][0]
type(a.get_data()[1])
# Out:
# numpy.ndarray

# %%
a.get_data()[1]
# Out:
# array([19094, 18947, 19545, 18740, 18844, 18172, 17328, 16959, 19537,
#        17181, 19926, 19033, 18722, 19999, 16792, 19232, 19517, 19068,
#        19202, 19436, 16872, 19045, 19144, 17584, 18665, 17068, 19272,
#        18300, 16659, 19406, 19197, 19566, 18041, 17046, 17861, 16835,
#        16595, 19502, 18200, 16627, 19513, 19141, 19189, 16856, 19859,
#        18430, 17639, 16752, 19246, 17159, 17924, 17099, 17444, 17399,
#        19419, 18303, 19973, 19845, 17650, 19237, 19627, 16756, 17665,
#        16885, 17465, 19626, 19943, 18606, 17048, 17856, 19081, 17779,
#        19740, 18711, 18265, 18213, 18824, 18789, 19847, 19190, 18061,
#        17123, 16880, 17861, 19187, 19717, 16799, 17328, 19701, 17169,
#        16598, 17007, 16606, 19586, 19331, 19613, 17567, 19049, 19658,
#        17426, 17603, 16704, 19833, 19038, 19328, 19392, 19665, 16823,
#        17174, 17875, 19161, 19636, 19431, 18880], dtype=int64)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9,4))

axes[0].boxplot(data["Age"])
axes[1].boxplot(data["Income"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2656125bb38>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2656125bf28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26561244e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x26561267898>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26561267be0>],
#  'means': []}

# %%
plt.bar(data2["Species"], data2['Sepal.Length'], width =0.3, color="pink", align="center")
plt.bar(data2['Species'], data2['Sepal.Width'], width = 0.3, color = 'lightblue',  align='center')
plt.tight_layout()

# %%
data3=pd.read_csv('MMix.csv')
data3.head()
# Out:
#    NewVolSales  Base Price  Radio     TV   InStore  Facebook  Twitter  \
# 0        19564   15.029276   245.0  145.4   15.452         0        0
# 1        19387   15.029276   314.0   66.0   16.388         0        0
# 2        23889   14.585093   324.0  155.1   62.692         0        0
# 3        20055   15.332887   298.0  114.5   16.573         0        0
# 4        20064   15.642632   279.0   96.5   41.504         0        0
#
#    WebCamp  Online Website Campaign   ...      tvst60      tvst70      tvst80  \
# 0        0       0               NaN  ...   87.240000  101.780000  116.320000
# 1        0       0               NaN  ...   74.496000   76.734000   76.064000
# 2        0       0               NaN  ...  122.858400  131.590200  139.292800
# 3        0       0               NaN  ...  117.843360  119.627060  119.458560
# 4        0       0               NaN  ...  105.037344  103.438118  101.091712
#
# ...

# %%
plt.plot(data3["NewVolSales"])
plt.xlabel("Week")
plt.ylabel("Volume Sales in thousands")
plt.title("Volume Sales")
# Out:
# Text(0.5, 1.0, 'Volume Sales')

# %%
plt.plot(data3["NewVolSales"], c="M", ls="--", marker="s", ms=6)
plt.xticks(rotation="vertical")
plt.xlabel('Volume Sales in 1000 units')
# Out:
# Text(0.5, 0, 'Volume Sales in 1000 units')
# C:\Users\Madhu-PC\Anaconda3\lib\site-packages\IPython\core\events.py:88: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   func(*args, **kwargs)

# %%
fig,ax1=plt.subplots()
ax1.plot(data3["NewVolSales"])

ax1.set_xlabel('time (w)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Volume Sales')

ax2=ax1.twinx()
ax2.plot(data3['Radio '], 'r')

ax2.set_ylabel('Radio')

fig.tight_layout()

# %%
plt.scatter(x=data['Age'],y = data['Income'], color = "magenta", alpha = 0.5)
plt.title('Relationship Between Age and Income')
plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
sns.FacetGrid(col="Department",data=data, col_wrap=50, aspect=1.2, size=4).map(plt.scatter,'Age','Income', s=20).fig.subplots_adjust(wspace=.3, hspace=.2)

# %%
g=sns.FacetGrid(data, col="MaritalStatus",row="Gender",col_order=["Single","Married","Divorced"])
g=g.map(plt.hist,"Income",bins=20,color="m")
g

# %%
kws=dict(s=50, linewidth=.5, edgecolor="w")
g=sns.FacetGrid(data,col="MaritalStatus",hue="Gender",palette="Set1",
               hue_order=["Male","Female"])
g=(g.map(plt.scatter,"Age","Income",**kws).add_legend())

# %%
plt.subplot(1,2,1)

plt.scatter(data["Age"],data["Income"],color="b")
plt.title("Scatter")

plt.subplot(1,2,2)
plt.boxplot(data["Income"])
plt.title("Boxplot")

plt.tight_layout()

# %%
plt.figure(figsize=(8,5))
plt.subplots_adjust(hspace=0.4, wspace=0.4)

plt.subplot(1,2,1)
plt.plot(data3["NewVolSales"], c="M", ls="--", marker="s", ms=6)
plt.xticks(rotation = 'vertical')
plt.title('Volume Sales in 1000 units')

plt.subplot(1,2,2)
plt.scatter(data3["NewVolSales"],data3["Base Price"], color="blue")
plt.title('NewVolSales vs. Base Price')

plt.tight_layout()

# %%
img=plt.imread("m.jpg")
print(img.shape)
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# (2048, 1444, 3)
